# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from IPython.display import Markdown

import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyCC1-_X_WvlRVuIf9lb93sOpa9ZP-dngXI"

# %%
# %pip install -U --quiet langchain-google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 1.6 MB/s eta 0:00:00

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model="gemini-pro")
result = llm.invoke("목에 증상이 전혀 없고 아프지 않은데 편도염일수가 있나요?")
Markdown(result.content)
# Out:
# 네, 목에 증상이 없어도 편도염일 수 있습니다. 일부 편도염은 아픈 목이 아닌 다른 증상으로 나타날 수 있습니다.
#
# **편도염의 무증상 증상:**
#
# * 발열
# * 오한
# * 피로
# * 두통
# * 근육통
# * 구역질 또는 구토
# * 목선의 부종 또는 압통
# * 편도의 발적 또는 붓기 (경우에 따라 볼 수 있음)
# * 목소리 변화
# * 침 삼키기 어려움
# * 턱 또는 귀 통증
# * 두통
# * 림프절 부종
#
# 귀하가 목에 증상이 없더라도 위에 언급한 다른 증상이 나타나면 편도염일 수 있으므로 의료진과 상담하는 것이 중요합니다.

# %%
# %pip install -U --quiet langchain tiktoken pypdf sentence_transformers chromadb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.9/815.9 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.0/284.0 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.0/509.0 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 25.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.1/41.1 kB 3.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 30.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 41.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.6/105.6 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 32.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 33.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 26.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 56.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 9.6 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires openai, which is not installed.

# %%
# from langchain.chains import RetrievalQA
# from langchain.chat_models import ChatOpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain_community.document_loaders.csv_loader import CSVLoader

# %%
loader = CSVLoader("/content/drive/MyDrive/rag/소아청소년과_QNA.csv", encoding='utf-8')
docs = loader.load()


text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=50)

texts = text_splitter.split_documents(docs)


from langchain.embeddings import HuggingFaceEmbeddings

model_name = "jhgan/ko-sbert-nli"
model_kwargs = {'device': 'cpu'}
encode_kwargs = {'normalize_embeddings': True}
hf = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

docsearch = Chroma.from_documents(texts, hf)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.46k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/620 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/538 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/495k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
 retriever = docsearch.as_retriever(
                                    search_type="mmr",
                                    search_kwargs={'k':3, 'fetch_k': 10})
 retriever.get_relevant_documents("목에 증상이 전혀 없고 아프지 않은데 편도염일수가 있나요?")
# Out:
# [Document(page_content="Date: 2018.07.01\nTitle: 편도선 수술한 사람은 편도 결석이 안생기나요,?\nQuestion: 편도선 수술한 사람은 편도 결석이 안생기나요,?어릴때 편도선 수술을 했는데입냄새가 걱정되서 찾아봤더니 편도 결석이 있으면 입냄새가 난다고 하더군요.저는 편도선 수술을 했는데 편도 결석이 생길 일은 없는 건가요??\nDoctors: ['전성호 전문의']\nHospitals: ['참길이비인후과의원']\nAnswers: ['안녕하세요, 하이닥 이비인후과 상담의 전성호 입니다.편도제거 수술 후에  편도결석이  걱정되어 질문하신 것 같습니다.편도결석이란  구개편도의 표면에 있는 움푹움푹 들어간 자리에  음식물찌꺼기가 쌓이면서  안에서 증식된 균과 섞이면서 만들어진 작은 알갱이를말합니다.   편도 제거 후라면  이러한  자리는 없겠지요.  다만.  일부 편도가남아있는 상태인지,  제거 후에  찌꺼기가  모일 자리는 없는지  등은 알 수 없습니다.     또한 입냄새의 원인은 다양하며,   편도결석이 없다고 입냄새가나지 않는 것은 아니지요.조금 더 자세한 사항은   진찰을 받고  상의하는 것이 좋겠습니다.답변이 좀 도움이 되었는지요?감사합니다. ( 이와 같은 답변은 참고사항이며, 법적인 책임이 동반되는 용도로 사용될 수 없습니다.  또한 정확한 검진과 판단은 이비인후과 진찰을 받고 전문의와 상의하여야 합니다. )']", metadata={'row': 3380, 'source': '/content/drive/MyDrive/rag/소아청소년과_QNA.csv'}),
#  Document(page_content="Date: 2022.02.10\nTitle: 식도염 이라고하는데 증상 애매모호 합니다\nQuestion: 역류성. 식도염 이라고 하는데 이비인후과에서. 또다른 이비인후과에서는. 후두염 이라고 하고. 위내시경 검사시. 물어보니 역류성 식도염 없다고 하네요 증상도 식도염증삼없습니다제 목 이물감 또는 약간가래로인한 불편감. 인데. 이증상 으로는. 식도염 약 밬에 없나요항상. 진료후 주는약은. 식도염 약만 주네요.   위 증상. 목 이물감 에는 어덯한 치료가 좋을까오ㅡ? 용각산. 어덯습니까\nDoctors: ['김민한 약사']\nHospitals: ['시원약국']\nAnswers: ['안녕하세요. 하이닥 상담약사 김민한입니다.가까운 약국에서 상의해보시죠처방약은 답이 없는데한약중에 목이물감에 쓰는 약들이 있습니다.(반하후박탕증 등)*각산은 폐가 말라서 예민할때 도움이 됩니다.']", metadata={'row': 426, 'source': '/content/drive/MyDrive/rag/소아청소년과_QNA.csv'}),
#  Document(page_content="Date: 2021.07.08\nTitle: 목이 부었어요\nQuestion: 목이 일주일쯤 된거같은데 계속 부어있어서 침이나 이런거 삼킬때 턱쪽이 들썩 하는거같고 아프진않아요 열이나 이런건 없고 목 정면 중간쪽이 부은느낌? 후레쉬로 입벌려서 보면 부은거나 그런건 안보이는데 안에좀 부은거같네요 목에 1cm 멍울도 여러개 잡히고 무슨병일까요?? 식습관에 변화를 줘야하나요? 간단하게할수있는 처치법이나 좀더 기다렸다가 내원해도되는지 궁금합니다\nDoctors: ['장형준 전문의', '장형준 전문의', '장형준 전문의']\nHospitals: ['잇츠비의원', '잇츠비의원', '잇츠비의원']\nAnswers: ['안녕하세요. 하이닥 이비인후과 상담의 장형준입니다.목이 부은 느낌때문에 문의 주셨군요.먼저 질문자분을 직접 진찰하지 않아 답변에 한계가 있음을 양지 바랍니다.목이 부은 느낌은 목 자체가 염증 등에 의해 부어서 그럴 수도 있고, 이물감때문에 그럴 수도 있습니다.두 경우 모두 정확한 진찰을 통해 원인을 밝힌 후 치료를 받아야 합니다.특히 목에 멍울이 여러개 잡히는 경우, 림프절이 부었을 가능성도 있으며, 이역시 그 원인을 찾고 원인 치료를 해야 한답니다.따라서 이비인후과에 조속히 방문하셔서 진찰을 받으시기 바랍니다.', '안녕하세요. 하이닥 외과 상담의 송슬기입니다.인후염에 의한 경부 림프절 종대일 가능성이 높아 보입니다. 가까운 곳에 이비인후과 나 내과 가셔서 진료를 보시는 것이 좋을 듯 합니다.', '안녕하세요. 하이닥 가정의학과 상담의 홍인표입니다.많이 불편하시겠네요. 목에 멍울은 임파선이 커져서 만져지는 것일 가능성이 높습니다. 일주일이나 되셨으니 진료를 받아보시는 것이 어떨까 싶습니다.']", metadata={'row': 5878, 'source': '/content/drive/MyDrive/rag/소아청소년과_QNA.csv'})]

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnableMap

template = """의사님의 의견을 바탕으로 다음과 같이 답변드리겠습니다:
{context}

질문: {question}
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
gemini = ChatGoogleGenerativeAI(model="gemini-pro", temperature = 0) # 답변의 일관성을 위한 0 값

chain = RunnableMap({
    "context": lambda x: retriever.get_relevant_documents(x['question']),
    "question": lambda x: x['question']
}) | prompt | gemini

# %%
chain.invoke({'question': "편도선 수술한 사람은 편도 결석이 안생기나요,"})
# Out:
# AIMessage(content='편도선 수술 후에도 편도 결석이 생길 수 있습니다. 편도선이 완전히 제거되지 않거나, 수술 후에 음식물 찌꺼기가 모일 수 있는 자리가 남아 있을 수 있기 때문입니다.')

# %%
from google.colab import drive
drive.mount("/content/drive")
# !cp -a /content/Gemini_RAG2 /content/drive/MyDrive/rag/gemini
